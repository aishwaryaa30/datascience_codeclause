# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryaa30/datascience_codeclause/blob/main/EDA_on_iris_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
iris =  pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# How many datapoints are there?
iris.shape
# Out:
# (150, 6)

# %%
# What are the features of the data?
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# How many flowers of each species?
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Plotting a 1-D Scatter Plot
iris_setosa = iris.loc[iris['Species'] == 'Iris-setosa']
iris_virginica = iris.loc[iris['Species'] == 'Iris-virginica']
iris_versicolor = iris.loc[iris['Species'] == 'Iris-versicolor']

plt.plot(iris_setosa['SepalLengthCm'], np.zeros_like(iris_setosa['SepalLengthCm']), 'o')
plt.plot(iris_virginica['SepalLengthCm'], np.zeros_like(iris_virginica['SepalLengthCm']), 'o')
plt.plot(iris_versicolor['SepalLengthCm'], np.zeros_like(iris_versicolor['SepalLengthCm']), 'o')
plt.grid()
plt.show()

# %%
# Plotting a 2-D graph
iris.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm')
plt.show()

# %%
sns.set_style('whitegrid')
sns.pairplot(iris, hue='Species', height=3).add_legend()
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue='Species', height=4).map(plt.scatter, 'PetalLengthCm', 'PetalWidthCm').add_legend()
plt.show()
